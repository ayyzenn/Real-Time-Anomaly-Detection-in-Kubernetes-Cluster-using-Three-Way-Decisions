# %%
import os
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Path to your dataset folder
dataset_folder = "./dataset/A4Benchmark"

# Functions for anomaly detection and evaluation
def sliding_window_std(df, column_name, window_size, threshold):
    results = []
    problem_vals = []  # List to store values that exceed the threshold

    for i in range(len(df)):
        # Calculate the window boundaries
        start_index = max(0, i - window_size // 2)
        end_index = min(len(df), i + window_size // 2 + 1)
        
        # Get the numbers within the window
        window = df[column_name].iloc[start_index:end_index]
        
        # Calculate the standard deviation of the window
        std_dev = window.std()
        
        # Append the result to the results list
        # result list conations 3 things (number, window,std of the window)
        results.append((i, df.iloc[i][column_name], window.tolist(), std_dev))
        # print(results[i],'\n')

        if len(results) <= 2:
            # print("Skipping iteration#", i)
            # print("##################################################")
            continue
            
        if len(results) >= 3:
            # print("val1:",results[-3][3])
            # print("val2:",results[-2][3])
            # print("current std:",std_dev)
            # print("current iteration:", i)
            # print("##################################################")

            avg_prev_results = (results[-2][3] + results[-3][3]) / 2
            threshold_value = avg_prev_results + threshold

            if std_dev > threshold_value:
                problem_vals.append((i - window_size // 2, window.iloc[-1]))

            # print('Problem list:', problem_vals)
    return results, problem_vals

def actual_anomaly(df):
    anomaly_rows = []

    # Iterate over each row in the DataFrame
    for i, row in df.iterrows():
        if row['anomaly'] == 1:
            # Append a tuple containing the row number and the value from the 'anomaly' column to the result list
            anomaly_rows.append((i, row['value']))
    # print(anomaly_rows)
    return anomaly_rows

def find_normal_values(original_lst, anomaly_lst):
    normal_values = []
    for num in original_lst:
        is_anomaly = False
        for win_num, value in anomaly_lst:
            if num == value:
                is_anomaly = True
                break
        if not is_anomaly:
            normal_values.append(num)
    return normal_values

def finding_row_number(original_lst, anomaly_lst):
    rows = []
    i = 1
    for num in original_lst:
        i +=1
        for win_num, value in anomaly_lst:
            if num == value:
                rows.append((i,num))
    return rows

def categorize_points(original_lst, anomaly_lst):
    normal = []
    seasonal = []
    anomalies = []

    for i, num in enumerate(original_lst):
        if num not in (value for _, value in anomaly_lst):
            normal.append((i, num))
        elif i % 12 == 0 or i % 168 ==0:
            seasonal.append((i, num))
        else:
            anomalies.append((i, num))

    return normal, seasonal, anomalies

def evaluate_anomaly_detection(true_labels, predicted_labels):
    # Generate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)

    # Extract true positives (TP) and true negatives (TN)
    TP = cm[1, 1]  # Actual positive (1) and predicted positive (1)
    TN = cm[0, 0]  # Actual negative (0) and predicted negative (0)
    FP = cm[0, 1]  # Actual negative (0) but predicted positive (1)
    FN = cm[1, 0]  # Actual positive (1) but predicted negative (0)

    # # Output true positives (TP), true negatives (TN), false positives (FP), and false negatives (FN)
    # print("True Positives (TP):", TP)
    # print("True Negatives (TN):", TN)
    # print("False Positives (FP):", FP)
    # print("False Negatives (FN):", FN)

    # # Generate classification report
    # report = classification_report(true_labels, predicted_labels)
    # print("\nClassification Report:\n", report)

    # Calculate Accuracy
    accuracy = (TP + TN) / (TP + TN + FP + FN)

    # Calculate Precision
    precision = TP / (TP + FP)

    # Calculate Recall
    recall = TP / (TP + FN)

    # Calculate F1-score
    f1_score = 2 * (precision * recall) / (precision + recall)

    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1-score:", f1_score)

    return accuracy

# Function to apply your model and calculate accuracy
def apply_model_and_calculate_accuracy(df, column_name, window_size, threshold):
    std_devs, anomalies = sliding_window_std(df, column_name, window_size, threshold)
    actual = actual_anomaly(df)
    normal_values = find_normal_values(df[column_name], anomalies)
    
    anomaly_row_list = finding_row_number(df[column_name], anomalies)
    normal_list, seasonal_anomalies, other_anomalies = categorize_points(df['value'], anomaly_row_list)
    
    # Initialize and mark predicted anomalies
    df['predicted_anomalies'] = 0
    for anomaly_index, _ in other_anomalies:
        df.at[anomaly_index, 'predicted_anomalies'] = 1
    
    # Evaluate anomaly detection and return accuracy
    accuracy = evaluate_anomaly_detection(df['anomaly'], df['predicted_anomalies'])
    return accuracy

# Dictionary to store accuracy results
accuracy_results = {}

# Specify the column name containing the data
column_name = 'value'

window_size = 16
threshold = 19  # Adjust threshold as needed

# Iterate through each file in the directory
for filename in sorted(os.listdir(dataset_folder)):
    if filename.endswith(".csv"):
        file_path = os.path.join(dataset_folder, filename)
        # Load CSV file
        df = pd.read_csv(file_path)
        print(f"File: {filename}")
        # Apply your model and calculate accuracy
        accuracy = apply_model_and_calculate_accuracy(df, column_name, window_size, threshold)
        print("#################################################")
        # Store accuracy result
        accuracy_results[filename] = accuracy

# # Print accuracy results
# for filename, accuracy in accuracy_results.items():
#     print(f"File: {filename}, Accuracy: {accuracy}")
# Out:
# File: A4Benchmark-TS1.csv
# Accuracy: 0.9940476190476191
# Precision: 0.8
# Recall: 0.3076923076923077
# F1-score: 0.4444444444444444
# #################################################
# File: A4Benchmark-TS10.csv
# Accuracy: 0.8636904761904762
# Precision: 0.012987012987012988
# Recall: 0.75
# F1-score: 0.02553191489361702
# #################################################
# File: A4Benchmark-TS100.csv
# Accuracy: 0.9940476190476191
# Precision: 0.2
# Recall: 0.14285714285714285
# F1-score: 0.16666666666666666
# #################################################
# File: A4Benchmark-TS11.csv
# Accuracy: 0.9761904761904762
# Precision: 0.09302325581395349
# Recall: 0.8
# F1-score: 0.16666666666666666
# #################################################
# File: A4Benchmark-TS12.csv
# Accuracy: 0.9851190476190477
# Precision: 0.08333333333333333
# Recall: 0.4
# F1-score: 0.13793103448275862
# #################################################
# File: A4Benchmark-TS13.csv
# Accuracy: 0.8005952380952381
# Precision: 0.03206997084548105
# Recall: 0.7857142857142857
# F1-score: 0.06162464985994398
# #################################################
# File: A4Benchmark-TS14.csv
# Accuracy: 0.919047619047619
# Precision: 0.06896551724137931
# Recall: 0.9090909090909091
# F1-score: 0.1282051282051282
# #################################################
# File: A4Benchmark-TS15.csv
# Accuracy: 0.9952380952380953
# Precision: 0.6666666666666666
# Recall: 0.2222222222222222
# F1-score: 0.3333333333333333
# #################################################
# File: A4Benchmark-TS16.csv
# /tmp/ipykernel_7037/1411734944.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Accuracy: 0.9160714285714285
# Precision: 0.0
# Recall: 0.0
# F1-score: nan
# #################################################
# File: A4Benchmark-TS17.csv
# Accuracy: 0.9363095238095238
# Precision: 0.04672897196261682
# Recall: 0.5
# F1-score: 0.08547008547008547
# #################################################
# File: A4Benchmark-TS18.csv
# /tmp/ipykernel_7037/1411734944.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Accuracy: 0.9803571428571428
# Precision: 0.0
# Recall: 0.0
# F1-score: nan
# #################################################
# File: A4Benchmark-TS19.csv
# Accuracy: 0.8232142857142857
# Precision: 0.023411371237458192
# Recall: 0.5833333333333334
# F1-score: 0.045016077170418
# #################################################
# File: A4Benchmark-TS2.csv
# Accuracy: 0.9982142857142857
# Precision: 1.0
# Recall: 0.4
# F1-score: 0.5714285714285715
# #################################################
# File: A4Benchmark-TS20.csv
# Accuracy: 0.7738095238095238
# Precision: 0.025839793281653745
# Recall: 0.7692307692307693
# F1-score: 0.049999999999999996
# #################################################
# File: A4Benchmark-TS21.csv
# Accuracy: 0.993452380952381
# Precision: 1.0
# Recall: 0.15384615384615385
# F1-score: 0.2666666666666667
# #################################################
# File: A4Benchmark-TS22.csv
# Accuracy: 0.9029761904761905
# Precision: 0.012738853503184714
# Recall: 0.2
# F1-score: 0.023952095808383235
# #################################################
# File: A4Benchmark-TS23.csv
# Accuracy: 0.7952380952380952
# Precision: 0.008670520231213872
# Recall: 0.75
# F1-score: 0.01714285714285714
# #################################################
# File: A4Benchmark-TS24.csv
# Accuracy: 0.9226190476190477
# Precision: 0.023622047244094488
# Recall: 0.3333333333333333
# F1-score: 0.04411764705882353
# #################################################
# File: A4Benchmark-TS25.csv
# Accuracy: 0.9279761904761905
# Precision: 0.008928571428571428
# Recall: 0.09090909090909091
# F1-score: 0.016260162601626015
# #################################################
# File: A4Benchmark-TS26.csv
# Accuracy: 0.8577380952380952
# Precision: 0.008298755186721992
# Recall: 1.0
# F1-score: 0.01646090534979424
# #################################################
# File: A4Benchmark-TS27.csv
# Accuracy: 0.9119047619047619
# Precision: 0.014598540145985401
# Recall: 0.13333333333333333
# F1-score: 0.02631578947368421
# #################################################
# File: A4Benchmark-TS28.csv
# Accuracy: 0.9279761904761905
# Precision: 0.056910569105691054
# Recall: 0.5833333333333334
# F1-score: 0.1037037037037037
# #################################################
# File: A4Benchmark-TS29.csv
# Accuracy: 0.9648809523809524
# Precision: 0.07547169811320754
# Recall: 0.2857142857142857
# F1-score: 0.11940298507462686
# #################################################
# File: A4Benchmark-TS3.csv
# Accuracy: 0.9553571428571429
# Precision: 0.04
# Recall: 0.5
# F1-score: 0.07407407407407407
# #################################################
# File: A4Benchmark-TS30.csv
# Accuracy: 0.8011904761904762
# Precision: 0.008955223880597015
# Recall: 0.6
# F1-score: 0.017647058823529415
# #################################################
# File: A4Benchmark-TS31.csv
# Accuracy: 0.9797619047619047
# Precision: 0.03125
# Recall: 0.25
# F1-score: 0.05555555555555555
# #################################################
# File: A4Benchmark-TS32.csv
# Accuracy: 0.8178571428571428
# Precision: 0.02572347266881029
# Recall: 0.7272727272727273
# F1-score: 0.049689440993788817
# #################################################
# File: A4Benchmark-TS33.csv
# Accuracy: 0.9839285714285714
# Precision: 0.07407407407407407
# Recall: 0.5
# F1-score: 0.12903225806451613
# #################################################
# File: A4Benchmark-TS34.csv
# Accuracy: 0.9958333333333333
# Precision: 1.0
# Recall: 0.125
# F1-score: 0.2222222222222222
# #################################################
# File: A4Benchmark-TS35.csv
# Accuracy: 0.9404761904761905
# Precision: 0.031914893617021274
# Recall: 0.25
# F1-score: 0.056603773584905655
# #################################################
# File: A4Benchmark-TS36.csv
# Accuracy: 0.9047619047619048
# Precision: 0.06060606060606061
# Recall: 0.6666666666666666
# F1-score: 0.1111111111111111
# #################################################
# File: A4Benchmark-TS37.csv
# Accuracy: 0.8660714285714286
# Precision: 0.004464285714285714
# Recall: 0.3333333333333333
# F1-score: 0.00881057268722467
# #################################################
# File: A4Benchmark-TS38.csv
# Accuracy: 0.9446428571428571
# Precision: 0.022727272727272728
# Recall: 0.2222222222222222
# F1-score: 0.041237113402061855
# #################################################
# File: A4Benchmark-TS39.csv
# Accuracy: 0.9083333333333333
# Precision: 0.06329113924050633
# Recall: 0.625
# F1-score: 0.1149425287356322
# #################################################
# File: A4Benchmark-TS4.csv
# Accuracy: 0.8666666666666667
# Precision: 0.017699115044247787
# Recall: 0.6666666666666666
# F1-score: 0.034482758620689655
# #################################################
# File: A4Benchmark-TS40.csv
# Accuracy: 0.9136904761904762
# Precision: 0.03355704697986577
# Recall: 0.8333333333333334
# F1-score: 0.06451612903225808
# #################################################
# File: A4Benchmark-TS41.csv
# Accuracy: 0.9577380952380953
# Precision: 0.08571428571428572
# Recall: 0.46153846153846156
# F1-score: 0.14457831325301204
# #################################################
# File: A4Benchmark-TS42.csv
# Accuracy: 0.9839285714285714
# Precision: 0.10344827586206896
# Recall: 0.75
# F1-score: 0.18181818181818182
# #################################################
# File: A4Benchmark-TS43.csv
# Accuracy: 0.9142857142857143
# Precision: 0.047619047619047616
# Recall: 0.6363636363636364
# F1-score: 0.08860759493670886
# #################################################
# File: A4Benchmark-TS44.csv
# Accuracy: 0.9482142857142857
# Precision: 0.08235294117647059
# Recall: 0.4375
# F1-score: 0.1386138613861386
# #################################################
# File: A4Benchmark-TS45.csv
# Accuracy: 0.7767857142857143
# Precision: 0.013227513227513227
# Recall: 0.7142857142857143
# F1-score: 0.025974025974025972
# #################################################
# File: A4Benchmark-TS46.csv
# Accuracy: 0.8101190476190476
# Precision: 0.021604938271604937
# Recall: 0.7777777777777778
# F1-score: 0.042042042042042045
# #################################################
# File: A4Benchmark-TS47.csv
# Accuracy: 0.8720238095238095
# Precision: 0.004629629629629629
# Recall: 1.0
# F1-score: 0.009216589861751152
# #################################################
# File: A4Benchmark-TS48.csv
# Accuracy: 0.969047619047619
# Precision: 0.12962962962962962
# Recall: 0.5833333333333334
# F1-score: 0.2121212121212121
# #################################################
# File: A4Benchmark-TS49.csv
# Accuracy: 0.9952380952380953
# Precision: 1.0
# Recall: 0.1111111111111111
# F1-score: 0.19999999999999998
# #################################################
# File: A4Benchmark-TS5.csv
# Accuracy: 0.9738095238095238
# Precision: 0.12
# Recall: 1.0
# F1-score: 0.21428571428571425
# #################################################
# File: A4Benchmark-TS50.csv
# Accuracy: 0.9666666666666667
# Precision: 0.05454545454545454
# Recall: 0.42857142857142855
# F1-score: 0.09677419354838708
# #################################################
# File: A4Benchmark-TS51.csv
# Accuracy: 0.9375
# Precision: 0.009433962264150943
# Recall: 1.0
# F1-score: 0.018691588785046728
# #################################################
# File: A4Benchmark-TS52.csv
# Accuracy: 0.9113095238095238
# Precision: 0.0273972602739726
# Recall: 0.36363636363636365
# F1-score: 0.05095541401273885
# #################################################
# File: A4Benchmark-TS53.csv
# Accuracy: 0.9178571428571428
# Precision: 0.014285714285714285
# Recall: 1.0
# F1-score: 0.028169014084507043
# #################################################
# File: A4Benchmark-TS54.csv
# Accuracy: 0.975
# Precision: 0.024390243902439025
# Recall: 0.3333333333333333
# F1-score: 0.04545454545454545
# #################################################
# File: A4Benchmark-TS55.csv
# Accuracy: 0.9339285714285714
# Precision: 0.017699115044247787
# Recall: 1.0
# F1-score: 0.034782608695652174
# #################################################
# File: A4Benchmark-TS56.csv
# Accuracy: 0.8904761904761904
# Precision: 0.03333333333333333
# Recall: 0.375
# F1-score: 0.06122448979591837
# #################################################
# File: A4Benchmark-TS57.csv
# Accuracy: 0.95
# Precision: 0.03571428571428571
# Recall: 0.5
# F1-score: 0.06666666666666667
# #################################################
# File: A4Benchmark-TS58.csv
# Accuracy: 0.9214285714285714
# Precision: 0.007936507936507936
# Recall: 0.125
# F1-score: 0.014925373134328358
# #################################################
# File: A4Benchmark-TS59.csv
# /tmp/ipykernel_7037/1411734944.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Accuracy: 0.944047619047619
# Precision: 0.0
# Recall: 0.0
# F1-score: nan
# #################################################
# File: A4Benchmark-TS6.csv
# Accuracy: 0.9494047619047619
# Precision: 0.03614457831325301
# Recall: 0.375
# F1-score: 0.06593406593406592
# #################################################
# File: A4Benchmark-TS60.csv
# Accuracy: 0.9738095238095238
# Precision: 0.023255813953488372
# Recall: 0.3333333333333333
# F1-score: 0.04347826086956522
# #################################################
# File: A4Benchmark-TS61.csv
# Accuracy: 0.9345238095238095
# Precision: 0.009174311926605505
# Recall: 0.3333333333333333
# F1-score: 0.01785714285714286
# #################################################
# File: A4Benchmark-TS62.csv
# Accuracy: 0.9
# Precision: 0.03048780487804878
# Recall: 0.35714285714285715
# F1-score: 0.05617977528089888
# #################################################
# File: A4Benchmark-TS63.csv
# Accuracy: 0.9958333333333333
# Precision: nan
# Recall: 0.0
# F1-score: nan
# #################################################
# File: A4Benchmark-TS64.csv
# /tmp/ipykernel_7037/1411734944.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   precision = TP / (TP + FP)
# Accuracy: 0.9976190476190476
# Precision: 1.0
# Recall: 0.2
# F1-score: 0.33333333333333337
# #################################################
# File: A4Benchmark-TS65.csv
# Accuracy: 0.8244047619047619
# Precision: 0.030201342281879196
# Recall: 0.6
# F1-score: 0.05750798722044729
# #################################################
# File: A4Benchmark-TS66.csv
# Accuracy: 0.9994047619047619
# Precision: nan
# Recall: 0.0
# F1-score: nan
# #################################################
# File: A4Benchmark-TS67.csv
# /tmp/ipykernel_7037/1411734944.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   precision = TP / (TP + FP)
# Accuracy: 0.8666666666666667
# Precision: 0.043478260869565216
# Recall: 0.7142857142857143
# F1-score: 0.08196721311475409
# #################################################
# File: A4Benchmark-TS68.csv
# Accuracy: 0.906547619047619
# Precision: 0.006329113924050633
# Recall: 1.0
# F1-score: 0.012578616352201257
# #################################################
# File: A4Benchmark-TS69.csv
# Accuracy: 0.8422619047619048
# Precision: 0.0037735849056603774
# Recall: 0.5
# F1-score: 0.00749063670411985
# #################################################
# File: A4Benchmark-TS7.csv
# Accuracy: 0.9625
# Precision: 0.13432835820895522
# Recall: 0.6428571428571429
# F1-score: 0.2222222222222222
# #################################################
# File: A4Benchmark-TS70.csv
# Accuracy: 0.9369047619047619
# Precision: 0.018867924528301886
# Recall: 0.5
# F1-score: 0.03636363636363636
# #################################################
# File: A4Benchmark-TS71.csv
# Accuracy: 0.9029761904761905
# Precision: 0.03067484662576687
# Recall: 0.5
# F1-score: 0.05780346820809248
# #################################################
# File: A4Benchmark-TS72.csv
# Accuracy: 0.7880952380952381
# Precision: 0.008403361344537815
# Recall: 0.6
# F1-score: 0.016574585635359115
# #################################################
# File: A4Benchmark-TS73.csv
# Accuracy: 0.8392857142857143
# Precision: 0.014652014652014652
# Recall: 0.8
# F1-score: 0.02877697841726619
# #################################################
# File: A4Benchmark-TS74.csv
# Accuracy: 0.9488095238095238
# Precision: 0.022727272727272728
# Recall: 1.0
# F1-score: 0.044444444444444446
# #################################################
# File: A4Benchmark-TS75.csv
# Accuracy: 0.8892857142857142
# Precision: 0.042328042328042326
# Recall: 0.6153846153846154
# F1-score: 0.0792079207920792
# #################################################
# File: A4Benchmark-TS76.csv
# Accuracy: 0.930952380952381
# Precision: 0.02702702702702703
# Recall: 0.2727272727272727
# F1-score: 0.049180327868852465
# #################################################
# File: A4Benchmark-TS77.csv
# Accuracy: 0.8232142857142857
# Precision: 0.029801324503311258
# Recall: 0.6923076923076923
# F1-score: 0.057142857142857134
# #################################################
# File: A4Benchmark-TS78.csv
# Accuracy: 0.9130952380952381
# Precision: 0.041379310344827586
# Recall: 0.46153846153846156
# F1-score: 0.0759493670886076
# #################################################
# File: A4Benchmark-TS79.csv
# Accuracy: 0.9494047619047619
# Precision: 0.011904761904761904
# Recall: 0.3333333333333333
# F1-score: 0.022988505747126436
# #################################################
# File: A4Benchmark-TS8.csv
# Accuracy: 0.9625
# Precision: 0.08333333333333333
# Recall: 0.38461538461538464
# F1-score: 0.136986301369863
# #################################################
# File: A4Benchmark-TS80.csv
# Accuracy: 0.8702380952380953
# Precision: 0.023148148148148147
# Recall: 0.4166666666666667
# F1-score: 0.043859649122807015
# #################################################
# File: A4Benchmark-TS81.csv
# Accuracy: 0.9416666666666667
# Precision: 0.031578947368421054
# Recall: 0.3333333333333333
# F1-score: 0.057692307692307696
# #################################################
# File: A4Benchmark-TS82.csv
# Accuracy: 0.7845238095238095
# Precision: 0.02197802197802198
# Recall: 0.5714285714285714
# F1-score: 0.04232804232804233
# #################################################
# File: A4Benchmark-TS83.csv
# Accuracy: 0.9547619047619048
# Precision: 0.013333333333333334
# Recall: 0.3333333333333333
# F1-score: 0.025641025641025644
# #################################################
# File: A4Benchmark-TS84.csv
# Accuracy: 0.9642857142857143
# Precision: 0.01694915254237288
# Recall: 0.3333333333333333
# F1-score: 0.03225806451612903
# #################################################
# File: A4Benchmark-TS85.csv
# Accuracy: 0.905952380952381
# Precision: 0.07738095238095238
# Recall: 0.8125
# F1-score: 0.14130434782608697
# #################################################
# File: A4Benchmark-TS86.csv
# Accuracy: 0.8642857142857143
# Precision: 0.05063291139240506
# Recall: 0.8
# F1-score: 0.09523809523809523
# #################################################
# File: A4Benchmark-TS87.csv
# Accuracy: 0.8595238095238096
# Precision: 0.004219409282700422
# Recall: 1.0
# F1-score: 0.008403361344537815
# #################################################
# File: A4Benchmark-TS88.csv
# Accuracy: 0.9547619047619048
# Precision: 0.1111111111111111
# Recall: 0.6923076923076923
# F1-score: 0.19148936170212763
# #################################################
# File: A4Benchmark-TS89.csv
# Accuracy: 0.8446428571428571
# Precision: 0.022727272727272728
# Recall: 0.6666666666666666
# F1-score: 0.04395604395604396
# #################################################
# File: A4Benchmark-TS9.csv
# Accuracy: 0.9273809523809524
# Precision: 0.008130081300813009
# Recall: 1.0
# F1-score: 0.01612903225806452
# #################################################
# File: A4Benchmark-TS90.csv
# Accuracy: 0.944047619047619
# Precision: 0.07291666666666667
# Recall: 0.5833333333333334
# F1-score: 0.12962962962962965
# #################################################
# File: A4Benchmark-TS91.csv
# Accuracy: 0.993452380952381
# Precision: 1.0
# Recall: 0.08333333333333333
# F1-score: 0.15384615384615385
# #################################################
# File: A4Benchmark-TS92.csv
# Accuracy: 0.9952380952380953
# Precision: 1.0
# Recall: 0.4666666666666667
# F1-score: 0.6363636363636364
# #################################################
# File: A4Benchmark-TS93.csv
# Accuracy: 0.8
# Precision: 0.017543859649122806
# Recall: 1.0
# F1-score: 0.034482758620689655
# #################################################
# File: A4Benchmark-TS94.csv
# Accuracy: 0.9285714285714286
# Precision: 0.042735042735042736
# Recall: 0.38461538461538464
# F1-score: 0.07692307692307691
# #################################################
# File: A4Benchmark-TS95.csv
# Accuracy: 0.8267857142857142
# Precision: 0.016891891891891893
# Recall: 1.0
# F1-score: 0.03322259136212625
# #################################################
# File: A4Benchmark-TS96.csv
# Accuracy: 0.8458333333333333
# Precision: 0.003861003861003861
# Recall: 0.5
# F1-score: 0.007662835249042146
# #################################################
# File: A4Benchmark-TS97.csv
# Accuracy: 0.9773809523809524
# Precision: 0.225
# Recall: 0.5625
# F1-score: 0.3214285714285714
# #################################################
# File: A4Benchmark-TS98.csv
# Accuracy: 0.9863095238095239
# Precision: 0.3
# Recall: 0.4
# F1-score: 0.34285714285714286
# #################################################
# File: A4Benchmark-TS99.csv
# Accuracy: 0.950595238095238
# Precision: 0.0410958904109589
# Recall: 0.1875
# F1-score: 0.06741573033707865
# #################################################

# %%
# Path to your dataset folder
dataset_folder = "./A4Benchmark/"

# Functions for anomaly detection and evaluation
def sliding_window_std(df, column_name, window_size, threshold):
    results = []
    problem_vals = []  # List to store values that exceed the threshold

    for i in range(len(df)):
        # Calculate the window boundaries
        start_index = max(0, i - window_size // 2)
        end_index = min(len(df), i + window_size // 2 + 1)
        
        # Get the numbers within the window
        window = df[column_name].iloc[start_index:end_index]
        
        # Calculate the standard deviation of the window
        std_dev = window.std()
        
        # Append the result to the results list
        # result list conations 3 things (number, window,std of the window)
        results.append((i, df.iloc[i][column_name], window.tolist(), std_dev))
        # print(results[i],'\n')

        if len(results) <= 2:
            # print("Skipping iteration#", i)
            # print("##################################################")
            continue
            
        if len(results) >= 3:
            # print("val1:",results[-3][3])
            # print("val2:",results[-2][3])
            # print("current std:",std_dev)
            # print("current iteration:", i)
            # print("##################################################")

            avg_prev_results = (results[-2][3] + results[-3][3]) / 2
            threshold_value = avg_prev_results + threshold

            if std_dev > threshold_value:
                problem_vals.append((i - window_size // 2, window.iloc[-1]))

            # print('Problem list:', problem_vals)
    return results, problem_vals

def actual_anomaly(df):
    anomaly_rows = []

    # Iterate over each row in the DataFrame
    for i, row in df.iterrows():
        if row['anomaly'] == 1:
            # Append a tuple containing the row number and the value from the 'anomaly' column to the result list
            anomaly_rows.append((i, row['value']))
    # print(anomaly_rows)
    return anomaly_rows

def find_normal_values(original_lst, anomaly_lst):
    normal_values = []
    for num in original_lst:
        is_anomaly = False
        for win_num, value in anomaly_lst:
            if num == value:
                is_anomaly = True
                break
        if not is_anomaly:
            normal_values.append(num)
    return normal_values

def finding_row_number(original_lst, anomaly_lst):
    rows = []
    i = 1
    for num in original_lst:
        i +=1
        for win_num, value in anomaly_lst:
            if num == value:
                rows.append((i,num))
    return rows

def categorize_points(original_lst, anomaly_lst):
    normal = []
    seasonal = []
    anomalies = []

    for i, num in enumerate(original_lst):
        if num not in (value for _, value in anomaly_lst):
            normal.append((i, num))
        elif i % 12 == 0 or i % 168 ==0:
            seasonal.append((i, num))
        else:
            anomalies.append((i, num))

    return normal, seasonal, anomalies

def evaluate_anomaly_detection(true_labels, predicted_labels):
    # Generate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)

    # Extract true positives (TP) and true negatives (TN)
    TP = cm[1, 1]  # Actual positive (1) and predicted positive (1)
    TN = cm[0, 0]  # Actual negative (0) and predicted negative (0)
    FP = cm[0, 1]  # Actual negative (0) but predicted positive (1)
    FN = cm[1, 0]  # Actual positive (1) but predicted negative (0)

    # # Output true positives (TP), true negatives (TN), false positives (FP), and false negatives (FN)
    # print("True Positives (TP):", TP)
    # print("True Negatives (TN):", TN)
    # print("False Positives (FP):", FP)
    # print("False Negatives (FN):", FN)

    # # Generate classification report
    # report = classification_report(true_labels, predicted_labels)
    # print("\nClassification Report:\n", report)

    # Calculate Accuracy
    accuracy = (TP + TN) / (TP + TN + FP + FN)

    # Calculate Precision
    # precision = TP / (TP + FP)

    # # Calculate Recall
    # recall = TP / (TP + FN)

    # # Calculate F1-score
    # f1_score = 2 * (precision * recall) / (precision + recall)

    # print("Accuracy:", accuracy)
    # print("Precision:", precision)
    # print("Recall:", recall)
    # print("F1-score:", f1_score)

    return accuracy

# Function to apply your model and calculate accuracy
def apply_model_and_calculate_accuracy(df, column_name, window_size, threshold):
    std_devs, anomalies = sliding_window_std(df, column_name, window_size, threshold)
    actual = actual_anomaly(df)
    normal_values = find_normal_values(df[column_name], anomalies)
    
    anomaly_row_list = finding_row_number(df[column_name], anomalies)
    normal_list, seasonal_anomalies, other_anomalies = categorize_points(df['value'], anomaly_row_list)
    
    # Initialize and mark predicted anomalies
    df['predicted_anomalies'] = 0
    for anomaly_index, _ in other_anomalies:
        df.at[anomaly_index, 'predicted_anomalies'] = 1
    
    # Evaluate anomaly detection and return accuracy
    accuracy = evaluate_anomaly_detection(df['anomaly'], df['predicted_anomalies'])
    return accuracy

# Dictionary to store accuracy results
accuracy_results = {}

# Specify the column name containing the data
column_name = 'value'

def grid_search(df, column_name):
    best_accuracy = 0
    best_window_size = 0
    best_threshold = 0
    
    # Define the range of values to search over
    window_sizes = range(3, 21)  # Adjust range as needed
    thresholds = range(5, 21)  # Adjust range as needed
    
    # Iterate over all combinations of window sizes and thresholds
    for window_size in window_sizes:
        for threshold in thresholds:
            # Apply your model and calculate accuracy
            accuracy = apply_model_and_calculate_accuracy(df, column_name, window_size, threshold)
            
            # Update best parameters if accuracy is improved
            if accuracy > best_accuracy:
                best_accuracy = accuracy
                best_window_size = window_size
                best_threshold = threshold
    
    return best_window_size, best_threshold, best_accuracy

# Iterate through each file in the directory
for filename in sorted(os.listdir(dataset_folder)):
    if filename.endswith(".csv"):
        file_path = os.path.join(dataset_folder, filename)
        # Load CSV file
        df = pd.read_csv(file_path)
        
        # Perform grid search to find the best window size and threshold
        best_window_size, best_threshold, best_accuracy = grid_search(df, column_name)
        
        # Print the best parameters and accuracy
        print(f"File: {filename}, Best Window Size: {best_window_size}, Best Threshold: {best_threshold}, Accuracy: {best_accuracy}")

# Print accuracy results
for filename, accuracy in accuracy_results.items():
    print(f"File: {filename}, Accuracy: {accuracy}")
# Out:
# File: Test_TS1.csv, Best Window Size: 20, Best Threshold: 20, Accuracy: 0.9665970772442589
# File: Test_TS12.csv, Best Window Size: 16, Best Threshold: 20, Accuracy: 0.8559498956158664
# File: Test_TS2.csv, Best Window Size: 20, Best Threshold: 20, Accuracy: 0.9102296450939458
# File: Test_TS7.csv, Best Window Size: 20, Best Threshold: 20, Accuracy: 0.9853862212943633
# File: Test_TS8.csv, Best Window Size: 16, Best Threshold: 20, Accuracy: 0.8058455114822547
# File: Train_TS1.csv, Best Window Size: 20, Best Threshold: 20, Accuracy: 0.9633638634471274
# File: Train_TS12.csv, Best Window Size: 16, Best Threshold: 20, Accuracy: 0.9342214820982515
# File: Train_TS2.csv, Best Window Size: 20, Best Threshold: 20, Accuracy: 0.9034138218151541
# File: Train_TS7.csv, Best Window Size: 16, Best Threshold: 20, Accuracy: 0.8376353039134055
# File: Train_TS8.csv, Best Window Size: 20, Best Threshold: 20, Accuracy: 0.8726061615320566

# %% [markdown]
# # 2 way

# %%
# Path to your dataset folder
dataset_folder = "./dataset/A4Benchmark"

# Functions for anomaly detection and evaluation
def sliding_window_std(df, column_name, window_size, threshold):
    results = []
    problem_vals = []  # List to store values that exceed the threshold

    for i in range(len(df)):
        # Calculate the window boundaries
        start_index = max(0, i - window_size // 2)
        end_index = min(len(df), i + window_size // 2 + 1)
        
        # Get the numbers within the window
        window = df[column_name].iloc[start_index:end_index]
        
        # Calculate the standard deviation of the window
        std_dev = window.std()
        
        # Append the result to the results list
        # result list conations 3 things (number, window,std of the window)
        results.append((i, df.iloc[i][column_name], window.tolist(), std_dev))
        # print(results[i],'\n')

        if len(results) <= 2:
            # print("Skipping iteration#", i)
            # print("##################################################")
            continue
            
        if len(results) >= 3:
            # print("val1:",results[-3][3])
            # print("val2:",results[-2][3])
            # print("current std:",std_dev)
            # print("current iteration:", i)
            # print("##################################################")

            avg_prev_results = (results[-2][3] + results[-3][3]) / 2
            threshold_value = avg_prev_results + threshold

            if std_dev > threshold_value:
                problem_vals.append((i - window_size // 2, window.iloc[-1]))

            # print('Problem list:', problem_vals)
    return results, problem_vals

def actual_anomaly(df):
    anomaly_rows = []

    # Iterate over each row in the DataFrame
    for i, row in df.iterrows():
        if row['anomaly'] == 1:
            # Append a tuple containing the row number and the value from the 'anomaly' column to the result list
            anomaly_rows.append((i, row['value']))
    # print(anomaly_rows)
    return anomaly_rows

def find_normal_values(original_lst, anomaly_lst):
    normal_values = []
    for num in original_lst:
        is_anomaly = False
        for win_num, value in anomaly_lst:
            if num == value:
                is_anomaly = True
                break
        if not is_anomaly:
            normal_values.append(num)
    return normal_values

def finding_row_number(original_lst, anomaly_lst):
    rows = []
    i = 1
    for num in original_lst:
        i +=1
        for win_num, value in anomaly_lst:
            if num == value:
                rows.append((i,num))
    return rows

def categorize_points(original_lst, anomaly_lst):
    normal = []
    seasonal = []
    anomalies = []

    for i, num in enumerate(original_lst):
        if num not in (value for _, value in anomaly_lst):
            normal.append((i, num))
        else:
            anomalies.append((i, num))

    return normal, anomalies

def evaluate_anomaly_detection(true_labels, predicted_labels):
    # Generate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)

    # Extract true positives (TP) and true negatives (TN)
    TP = cm[1, 1]  # Actual positive (1) and predicted positive (1)
    TN = cm[0, 0]  # Actual negative (0) and predicted negative (0)
    FP = cm[0, 1]  # Actual negative (0) but predicted positive (1)
    FN = cm[1, 0]  # Actual positive (1) but predicted negative (0)

    # Output true positives (TP), true negatives (TN), false positives (FP), and false negatives (FN)
    print("True Positives (TP):", TP)
    print("True Negatives (TN):", TN)
    print("False Positives (FP):", FP)
    print("False Negatives (FN):", FN)

    # # Generate classification report
    # report = classification_report(true_labels, predicted_labels)
    # print("\nClassification Report:\n", report)

    # Calculate Accuracy
    accuracy = (TP + TN) / (TP + TN + FP + FN)

    # Calculate Precision
    precision = TP / (TP + FP)

    # Calculate Recall
    recall = TP / (TP + FN)

    # Calculate F1-score
    f1_score = 2 * (precision * recall) / (precision + recall)

    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1-score:", f1_score)

    return accuracy

# Function to apply your model and calculate accuracy
def apply_model_and_calculate_accuracy(df, column_name, window_size, threshold):
    std_devs, anomalies = sliding_window_std(df, column_name, window_size, threshold)
    actual = actual_anomaly(df)
    normal_values = find_normal_values(df[column_name], anomalies)
    
    anomaly_row_list = finding_row_number(df[column_name], anomalies)
    normal_list, other_anomalies = categorize_points(df['value'], anomaly_row_list)
    
    # Initialize and mark predicted anomalies
    df['predicted_anomalies'] = 0
    for anomaly_index, _ in other_anomalies:
        df.at[anomaly_index, 'predicted_anomalies'] = 1
    
    # Evaluate anomaly detection and return accuracy
    accuracy = evaluate_anomaly_detection(df['anomaly'], df['predicted_anomalies'])
    return accuracy

# Dictionary to store accuracy results
accuracy_results = {}

# Specify the column name containing the data
column_name = 'value'

window_size = 5
threshold = 10  # Adjust threshold as needed

# Iterate through each file in the directory
for filename in sorted(os.listdir(dataset_folder)):
    if filename.endswith(".csv"):
        file_path = os.path.join(dataset_folder, filename)
        # Load CSV file
        df = pd.read_csv(file_path)
        print(f"File: {filename}")
        # Apply your model and calculate accuracy
        accuracy = apply_model_and_calculate_accuracy(df, column_name, window_size, threshold)
        print("#################################################")
        # Store accuracy result
        accuracy_results[filename] = accuracy

# # Print accuracy results
# for filename, accuracy in accuracy_results.items():
#     print(f"File: {filename}, Accuracy: {accuracy}")
# Out:
# File: A4Benchmark-TS1.csv
# True Positives (TP): 11
# True Negatives (TN): 1289
# False Positives (FP): 378
# False Negatives (FN): 2
# Accuracy: 0.7738095238095238
# Precision: 0.028277634961439587
# Recall: 0.8461538461538461
# F1-score: 0.05472636815920398
# #################################################
# File: A4Benchmark-TS10.csv
# True Positives (TP): 4
# True Negatives (TN): 990
# False Positives (FP): 686
# False Negatives (FN): 0
# Accuracy: 0.5916666666666667
# Precision: 0.005797101449275362
# Recall: 1.0
# F1-score: 0.011527377521613834
# #################################################
# File: A4Benchmark-TS100.csv
# True Positives (TP): 6
# True Negatives (TN): 1112
# False Positives (FP): 561
# False Negatives (FN): 1
# Accuracy: 0.6654761904761904
# Precision: 0.010582010582010581
# Recall: 0.8571428571428571
# F1-score: 0.020905923344947733
# #################################################
# File: A4Benchmark-TS11.csv
# True Positives (TP): 5
# True Negatives (TN): 1069
# False Positives (FP): 606
# False Negatives (FN): 0
# Accuracy: 0.6392857142857142
# Precision: 0.008183306055646482
# Recall: 1.0
# F1-score: 0.016233766233766236
# #################################################
# File: A4Benchmark-TS12.csv
# True Positives (TP): 4
# True Negatives (TN): 1275
# False Positives (FP): 400
# False Negatives (FN): 1
# Accuracy: 0.7613095238095238
# Precision: 0.009900990099009901
# Recall: 0.8
# F1-score: 0.019559902200488997
# #################################################
# File: A4Benchmark-TS13.csv
# True Positives (TP): 13
# True Negatives (TN): 908
# False Positives (FP): 758
# False Negatives (FN): 1
# Accuracy: 0.5482142857142858
# Precision: 0.016861219195849545
# Recall: 0.9285714285714286
# F1-score: 0.033121019108280254
# #################################################
# File: A4Benchmark-TS14.csv
# True Positives (TP): 10
# True Negatives (TN): 1079
# False Positives (FP): 590
# False Negatives (FN): 1
# Accuracy: 0.6482142857142857
# Precision: 0.016666666666666666
# Recall: 0.9090909090909091
# F1-score: 0.03273322422258592
# #################################################
# File: A4Benchmark-TS15.csv
# True Positives (TP): 8
# True Negatives (TN): 1164
# False Positives (FP): 507
# False Negatives (FN): 1
# Accuracy: 0.6976190476190476
# Precision: 0.015533980582524271
# Recall: 0.8888888888888888
# F1-score: 0.030534351145038163
# #################################################
# File: A4Benchmark-TS16.csv
# True Positives (TP): 1
# True Negatives (TN): 948
# False Positives (FP): 731
# False Negatives (FN): 0
# Accuracy: 0.5648809523809524
# Precision: 0.001366120218579235
# Recall: 1.0
# F1-score: 0.002728512960436562
# #################################################
# File: A4Benchmark-TS17.csv
# True Positives (TP): 8
# True Negatives (TN): 994
# False Positives (FP): 676
# False Negatives (FN): 2
# Accuracy: 0.5964285714285714
# Precision: 0.011695906432748537
# Recall: 0.8
# F1-score: 0.023054755043227664
# #################################################
# File: A4Benchmark-TS18.csv
# True Positives (TP): 1
# True Negatives (TN): 1075
# False Positives (FP): 604
# False Negatives (FN): 0
# Accuracy: 0.6404761904761904
# Precision: 0.001652892561983471
# Recall: 1.0
# F1-score: 0.0033003300330033004
# #################################################
# File: A4Benchmark-TS19.csv
# True Positives (TP): 12
# True Negatives (TN): 944
# False Positives (FP): 724
# False Negatives (FN): 0
# Accuracy: 0.569047619047619
# Precision: 0.016304347826086956
# Recall: 1.0
# F1-score: 0.03208556149732621
# #################################################
# File: A4Benchmark-TS2.csv
# True Positives (TP): 5
# True Negatives (TN): 1132
# False Positives (FP): 543
# False Negatives (FN): 0
# Accuracy: 0.6767857142857143
# Precision: 0.009124087591240875
# Recall: 1.0
# F1-score: 0.018083182640144666
# #################################################
# File: A4Benchmark-TS20.csv
# True Positives (TP): 13
# True Negatives (TN): 933
# False Positives (FP): 734
# False Negatives (FN): 0
# Accuracy: 0.5630952380952381
# Precision: 0.01740294511378849
# Recall: 1.0
# F1-score: 0.034210526315789476
# #################################################
# File: A4Benchmark-TS21.csv
# True Positives (TP): 11
# True Negatives (TN): 1134
# False Positives (FP): 533
# False Negatives (FN): 2
# Accuracy: 0.6815476190476191
# Precision: 0.02022058823529412
# Recall: 0.8461538461538461
# F1-score: 0.03949730700179534
# #################################################
# File: A4Benchmark-TS22.csv
# True Positives (TP): 9
# True Negatives (TN): 1127
# False Positives (FP): 543
# False Negatives (FN): 1
# Accuracy: 0.6761904761904762
# Precision: 0.016304347826086956
# Recall: 0.9
# F1-score: 0.03202846975088968
# #################################################
# File: A4Benchmark-TS23.csv
# True Positives (TP): 3
# True Negatives (TN): 912
# False Positives (FP): 764
# False Negatives (FN): 1
# Accuracy: 0.5446428571428571
# Precision: 0.003911342894393742
# Recall: 0.75
# F1-score: 0.007782101167315176
# #################################################
# File: A4Benchmark-TS24.csv
# True Positives (TP): 9
# True Negatives (TN): 997
# False Positives (FP): 674
# False Negatives (FN): 0
# Accuracy: 0.5988095238095238
# Precision: 0.013177159590043924
# Recall: 1.0
# F1-score: 0.026011560693641623
# #################################################
# File: A4Benchmark-TS25.csv
# True Positives (TP): 7
# True Negatives (TN): 1187
# False Positives (FP): 482
# False Negatives (FN): 4
# Accuracy: 0.7107142857142857
# Precision: 0.014314928425357873
# Recall: 0.6363636363636364
# F1-score: 0.028
# #################################################
# File: A4Benchmark-TS26.csv
# True Positives (TP): 2
# True Negatives (TN): 1002
# False Positives (FP): 676
# False Negatives (FN): 0
# Accuracy: 0.5976190476190476
# Precision: 0.0029498525073746312
# Recall: 1.0
# F1-score: 0.0058823529411764705
# #################################################
# File: A4Benchmark-TS27.csv
# True Positives (TP): 11
# True Negatives (TN): 1069
# False Positives (FP): 596
# False Negatives (FN): 4
# Accuracy: 0.6428571428571429
# Precision: 0.018121911037891267
# Recall: 0.7333333333333333
# F1-score: 0.03536977491961414
# #################################################
# File: A4Benchmark-TS28.csv
# True Positives (TP): 11
# True Negatives (TN): 964
# False Positives (FP): 704
# False Negatives (FN): 1
# Accuracy: 0.5803571428571429
# Precision: 0.015384615384615385
# Recall: 0.9166666666666666
# F1-score: 0.030261348005502064
# #################################################
# File: A4Benchmark-TS29.csv
# True Positives (TP): 11
# True Negatives (TN): 1053
# False Positives (FP): 613
# False Negatives (FN): 3
# Accuracy: 0.6333333333333333
# Precision: 0.017628205128205128
# Recall: 0.7857142857142857
# F1-score: 0.034482758620689655
# #################################################
# File: A4Benchmark-TS3.csv
# True Positives (TP): 5
# True Negatives (TN): 1091
# False Positives (FP): 583
# False Negatives (FN): 1
# Accuracy: 0.6523809523809524
# Precision: 0.008503401360544218
# Recall: 0.8333333333333334
# F1-score: 0.016835016835016838
# #################################################
# File: A4Benchmark-TS30.csv
# True Positives (TP): 5
# True Negatives (TN): 928
# False Positives (FP): 747
# False Negatives (FN): 0
# Accuracy: 0.5553571428571429
# Precision: 0.006648936170212766
# Recall: 1.0
# F1-score: 0.013210039630118891
# #################################################
# File: A4Benchmark-TS31.csv
# True Positives (TP): 4
# True Negatives (TN): 1445
# False Positives (FP): 231
# False Negatives (FN): 0
# Accuracy: 0.8625
# Precision: 0.01702127659574468
# Recall: 1.0
# F1-score: 0.03347280334728033
# #################################################
# File: A4Benchmark-TS32.csv
# True Positives (TP): 10
# True Negatives (TN): 1000
# False Positives (FP): 669
# False Negatives (FN): 1
# Accuracy: 0.6011904761904762
# Precision: 0.014727540500736377
# Recall: 0.9090909090909091
# F1-score: 0.028985507246376815
# #################################################
# File: A4Benchmark-TS33.csv
# True Positives (TP): 4
# True Negatives (TN): 1174
# False Positives (FP): 502
# False Negatives (FN): 0
# Accuracy: 0.7011904761904761
# Precision: 0.007905138339920948
# Recall: 1.0
# F1-score: 0.01568627450980392
# #################################################
# File: A4Benchmark-TS34.csv
# True Positives (TP): 7
# True Negatives (TN): 1433
# False Positives (FP): 239
# False Negatives (FN): 1
# Accuracy: 0.8571428571428571
# Precision: 0.028455284552845527
# Recall: 0.875
# F1-score: 0.05511811023622047
# #################################################
# File: A4Benchmark-TS35.csv
# True Positives (TP): 11
# True Negatives (TN): 1125
# False Positives (FP): 543
# False Negatives (FN): 1
# Accuracy: 0.6761904761904762
# Precision: 0.019855595667870037
# Recall: 0.9166666666666666
# F1-score: 0.03886925795053004
# #################################################
# File: A4Benchmark-TS36.csv
# True Positives (TP): 15
# True Negatives (TN): 936
# False Positives (FP): 729
# False Negatives (FN): 0
# Accuracy: 0.5660714285714286
# Precision: 0.020161290322580645
# Recall: 1.0
# F1-score: 0.03952569169960474
# #################################################
# File: A4Benchmark-TS37.csv
# True Positives (TP): 2
# True Negatives (TN): 999
# False Positives (FP): 678
# False Negatives (FN): 1
# Accuracy: 0.5958333333333333
# Precision: 0.0029411764705882353
# Recall: 0.6666666666666666
# F1-score: 0.005856515373352855
# #################################################
# File: A4Benchmark-TS38.csv
# True Positives (TP): 9
# True Negatives (TN): 1151
# False Positives (FP): 520
# False Negatives (FN): 0
# Accuracy: 0.6904761904761905
# Precision: 0.017013232514177693
# Recall: 1.0
# F1-score: 0.033457249070631974
# #################################################
# File: A4Benchmark-TS39.csv
# True Positives (TP): 16
# True Negatives (TN): 957
# False Positives (FP): 707
# False Negatives (FN): 0
# Accuracy: 0.5791666666666667
# Precision: 0.022130013831258646
# Recall: 1.0
# F1-score: 0.04330175913396482
# #################################################
# File: A4Benchmark-TS4.csv
# True Positives (TP): 6
# True Negatives (TN): 953
# False Positives (FP): 721
# False Negatives (FN): 0
# Accuracy: 0.5708333333333333
# Precision: 0.008253094910591471
# Recall: 1.0
# F1-score: 0.01637107776261937
# #################################################
# File: A4Benchmark-TS40.csv
# True Positives (TP): 6
# True Negatives (TN): 1092
# False Positives (FP): 582
# False Negatives (FN): 0
# Accuracy: 0.6535714285714286
# Precision: 0.01020408163265306
# Recall: 1.0
# F1-score: 0.020202020202020204
# #################################################
# File: A4Benchmark-TS41.csv
# True Positives (TP): 11
# True Negatives (TN): 981
# False Positives (FP): 686
# False Negatives (FN): 2
# Accuracy: 0.5904761904761905
# Precision: 0.015781922525107604
# Recall: 0.8461538461538461
# F1-score: 0.030985915492957747
# #################################################
# File: A4Benchmark-TS42.csv
# True Positives (TP): 4
# True Negatives (TN): 1154
# False Positives (FP): 522
# False Negatives (FN): 0
# Accuracy: 0.6892857142857143
# Precision: 0.0076045627376425855
# Recall: 1.0
# F1-score: 0.015094339622641508
# #################################################
# File: A4Benchmark-TS43.csv
# True Positives (TP): 10
# True Negatives (TN): 1025
# False Positives (FP): 644
# False Negatives (FN): 1
# Accuracy: 0.6160714285714286
# Precision: 0.01529051987767584
# Recall: 0.9090909090909091
# F1-score: 0.030075187969924814
# #################################################
# File: A4Benchmark-TS44.csv
# True Positives (TP): 13
# True Negatives (TN): 1101
# False Positives (FP): 563
# False Negatives (FN): 3
# Accuracy: 0.6630952380952381
# Precision: 0.022569444444444444
# Recall: 0.8125
# F1-score: 0.04391891891891892
# #################################################
# File: A4Benchmark-TS45.csv
# True Positives (TP): 7
# True Negatives (TN): 920
# False Positives (FP): 753
# False Negatives (FN): 0
# Accuracy: 0.5517857142857143
# Precision: 0.009210526315789473
# Recall: 1.0
# F1-score: 0.01825293350717079
# #################################################
# File: A4Benchmark-TS46.csv
# True Positives (TP): 9
# True Negatives (TN): 959
# False Positives (FP): 712
# False Negatives (FN): 0
# Accuracy: 0.5761904761904761
# Precision: 0.012482662968099861
# Recall: 1.0
# F1-score: 0.024657534246575342
# #################################################
# File: A4Benchmark-TS47.csv
# True Positives (TP): 1
# True Negatives (TN): 970
# False Positives (FP): 709
# False Negatives (FN): 0
# Accuracy: 0.5779761904761904
# Precision: 0.0014084507042253522
# Recall: 1.0
# F1-score: 0.0028129395218002813
# #################################################
# File: A4Benchmark-TS48.csv
# True Positives (TP): 12
# True Negatives (TN): 1098
# False Positives (FP): 570
# False Negatives (FN): 0
# Accuracy: 0.6607142857142857
# Precision: 0.020618556701030927
# Recall: 1.0
# F1-score: 0.04040404040404041
# #################################################
# File: A4Benchmark-TS49.csv
# True Positives (TP): 6
# True Negatives (TN): 1363
# False Positives (FP): 308
# False Negatives (FN): 3
# Accuracy: 0.8148809523809524
# Precision: 0.01910828025477707
# Recall: 0.6666666666666666
# F1-score: 0.03715170278637771
# #################################################
# File: A4Benchmark-TS5.csv
# True Positives (TP): 6
# True Negatives (TN): 1062
# False Positives (FP): 612
# False Negatives (FN): 0
# Accuracy: 0.6357142857142857
# Precision: 0.009708737864077669
# Recall: 1.0
# F1-score: 0.01923076923076923
# #################################################
# File: A4Benchmark-TS50.csv
# True Positives (TP): 7
# True Negatives (TN): 1255
# False Positives (FP): 418
# False Negatives (FN): 0
# Accuracy: 0.7511904761904762
# Precision: 0.01647058823529412
# Recall: 1.0
# F1-score: 0.03240740740740741
# #################################################
# File: A4Benchmark-TS51.csv
# True Positives (TP): 1
# True Negatives (TN): 978
# False Positives (FP): 701
# False Negatives (FN): 0
# Accuracy: 0.5827380952380953
# Precision: 0.0014245014245014246
# Recall: 1.0
# F1-score: 0.0028449502133712666
# #################################################
# File: A4Benchmark-TS52.csv
# True Positives (TP): 10
# True Negatives (TN): 1008
# False Positives (FP): 661
# False Negatives (FN): 1
# Accuracy: 0.6059523809523809
# Precision: 0.014903129657228018
# Recall: 0.9090909090909091
# F1-score: 0.029325513196480937
# #################################################
# File: A4Benchmark-TS53.csv
# True Positives (TP): 2
# True Negatives (TN): 986
# False Positives (FP): 692
# False Negatives (FN): 0
# Accuracy: 0.5880952380952381
# Precision: 0.002881844380403458
# Recall: 1.0
# F1-score: 0.005747126436781608
# #################################################
# File: A4Benchmark-TS54.csv
# True Positives (TP): 3
# True Negatives (TN): 1046
# False Positives (FP): 631
# False Negatives (FN): 0
# Accuracy: 0.6244047619047619
# Precision: 0.00473186119873817
# Recall: 1.0
# F1-score: 0.009419152276295134
# #################################################
# File: A4Benchmark-TS55.csv
# True Positives (TP): 2
# True Negatives (TN): 1040
# False Positives (FP): 638
# False Negatives (FN): 0
# Accuracy: 0.6202380952380953
# Precision: 0.003125
# Recall: 1.0
# F1-score: 0.006230529595015576
# #################################################
# File: A4Benchmark-TS56.csv
# True Positives (TP): 12
# True Negatives (TN): 1024
# False Positives (FP): 640
# False Negatives (FN): 4
# Accuracy: 0.6166666666666667
# Precision: 0.018404907975460124
# Recall: 0.75
# F1-score: 0.03592814371257485
# #################################################
# File: A4Benchmark-TS57.csv
# True Positives (TP): 5
# True Negatives (TN): 1041
# False Positives (FP): 633
# False Negatives (FN): 1
# Accuracy: 0.6226190476190476
# Precision: 0.007836990595611285
# Recall: 0.8333333333333334
# F1-score: 0.015527950310559004
# #################################################
# File: A4Benchmark-TS58.csv
# True Positives (TP): 8
# True Negatives (TN): 1053
# False Positives (FP): 619
# False Negatives (FN): 0
# Accuracy: 0.631547619047619
# Precision: 0.012759170653907496
# Recall: 1.0
# F1-score: 0.02519685039370079
# #################################################
# File: A4Benchmark-TS59.csv
# True Positives (TP): 1
# True Negatives (TN): 1157
# False Positives (FP): 522
# False Negatives (FN): 0
# Accuracy: 0.6892857142857143
# Precision: 0.0019120458891013384
# Recall: 1.0
# F1-score: 0.003816793893129771
# #################################################
# File: A4Benchmark-TS6.csv
# True Positives (TP): 6
# True Negatives (TN): 992
# False Positives (FP): 680
# False Negatives (FN): 2
# Accuracy: 0.594047619047619
# Precision: 0.008746355685131196
# Recall: 0.75
# F1-score: 0.01729106628242075
# #################################################
# File: A4Benchmark-TS60.csv
# True Positives (TP): 1
# True Negatives (TN): 1047
# False Positives (FP): 630
# False Negatives (FN): 2
# Accuracy: 0.6238095238095238
# Precision: 0.001584786053882726
# Recall: 0.3333333333333333
# F1-score: 0.003154574132492114
# #################################################
# File: A4Benchmark-TS61.csv
# True Positives (TP): 2
# True Negatives (TN): 963
# False Positives (FP): 714
# False Negatives (FN): 1
# Accuracy: 0.5744047619047619
# Precision: 0.002793296089385475
# Recall: 0.6666666666666666
# F1-score: 0.005563282336578581
# #################################################
# File: A4Benchmark-TS62.csv
# True Positives (TP): 9
# True Negatives (TN): 1244
# False Positives (FP): 422
# False Negatives (FN): 5
# Accuracy: 0.7458333333333333
# Precision: 0.02088167053364269
# Recall: 0.6428571428571429
# F1-score: 0.04044943820224719
# #################################################
# File: A4Benchmark-TS63.csv
# True Positives (TP): 7
# True Negatives (TN): 1451
# False Positives (FP): 222
# False Negatives (FN): 0
# Accuracy: 0.8678571428571429
# Precision: 0.03056768558951965
# Recall: 1.0
# F1-score: 0.059322033898305086
# #################################################
# File: A4Benchmark-TS64.csv
# True Positives (TP): 4
# True Negatives (TN): 1242
# False Positives (FP): 433
# False Negatives (FN): 1
# Accuracy: 0.7416666666666667
# Precision: 0.009153318077803204
# Recall: 0.8
# F1-score: 0.01809954751131222
# #################################################
# File: A4Benchmark-TS65.csv
# True Positives (TP): 15
# True Negatives (TN): 935
# False Positives (FP): 730
# False Negatives (FN): 0
# Accuracy: 0.5654761904761905
# Precision: 0.020134228187919462
# Recall: 1.0
# F1-score: 0.03947368421052631
# #################################################
# File: A4Benchmark-TS66.csv
# True Positives (TP): 1
# True Negatives (TN): 1177
# False Positives (FP): 502
# False Negatives (FN): 0
# Accuracy: 0.7011904761904761
# Precision: 0.0019880715705765406
# Recall: 1.0
# F1-score: 0.003968253968253968
# #################################################
# File: A4Benchmark-TS67.csv
# True Positives (TP): 13
# True Negatives (TN): 938
# False Positives (FP): 728
# False Negatives (FN): 1
# Accuracy: 0.5660714285714286
# Precision: 0.017543859649122806
# Recall: 0.9285714285714286
# F1-score: 0.03443708609271523
# #################################################
# File: A4Benchmark-TS68.csv
# True Positives (TP): 1
# True Negatives (TN): 984
# False Positives (FP): 695
# False Negatives (FN): 0
# Accuracy: 0.5863095238095238
# Precision: 0.0014367816091954023
# Recall: 1.0
# F1-score: 0.0028694404591104736
# #################################################
# File: A4Benchmark-TS69.csv
# True Positives (TP): 2
# True Negatives (TN): 984
# False Positives (FP): 694
# False Negatives (FN): 0
# Accuracy: 0.5869047619047619
# Precision: 0.0028735632183908046
# Recall: 1.0
# F1-score: 0.005730659025787966
# #################################################
# File: A4Benchmark-TS7.csv
# True Positives (TP): 14
# True Negatives (TN): 1156
# False Positives (FP): 510
# False Negatives (FN): 0
# Accuracy: 0.6964285714285714
# Precision: 0.026717557251908396
# Recall: 1.0
# F1-score: 0.0520446096654275
# #################################################
# File: A4Benchmark-TS70.csv
# True Positives (TP): 4
# True Negatives (TN): 1032
# False Positives (FP): 644
# False Negatives (FN): 0
# Accuracy: 0.6166666666666667
# Precision: 0.006172839506172839
# Recall: 1.0
# F1-score: 0.012269938650306747
# #################################################
# File: A4Benchmark-TS71.csv
# True Positives (TP): 9
# True Negatives (TN): 1162
# False Positives (FP): 508
# False Negatives (FN): 1
# Accuracy: 0.6970238095238095
# Precision: 0.017408123791102514
# Recall: 0.9
# F1-score: 0.03415559772296015
# #################################################
# File: A4Benchmark-TS72.csv
# True Positives (TP): 4
# True Negatives (TN): 954
# False Positives (FP): 721
# False Negatives (FN): 1
# Accuracy: 0.5702380952380952
# Precision: 0.005517241379310344
# Recall: 0.8
# F1-score: 0.010958904109589041
# #################################################
# File: A4Benchmark-TS73.csv
# True Positives (TP): 5
# True Negatives (TN): 912
# False Positives (FP): 763
# False Negatives (FN): 0
# Accuracy: 0.5458333333333333
# Precision: 0.006510416666666667
# Recall: 1.0
# F1-score: 0.012936610608020697
# #################################################
# File: A4Benchmark-TS74.csv
# True Positives (TP): 2
# True Negatives (TN): 1003
# False Positives (FP): 675
# False Negatives (FN): 0
# Accuracy: 0.5982142857142857
# Precision: 0.0029542097488921715
# Recall: 1.0
# F1-score: 0.0058910162002945516
# #################################################
# File: A4Benchmark-TS75.csv
# True Positives (TP): 11
# True Negatives (TN): 1000
# False Positives (FP): 667
# False Negatives (FN): 2
# Accuracy: 0.6017857142857143
# Precision: 0.016224188790560472
# Recall: 0.8461538461538461
# F1-score: 0.031837916063675836
# #################################################
# File: A4Benchmark-TS76.csv
# True Positives (TP): 9
# True Negatives (TN): 1105
# False Positives (FP): 564
# False Negatives (FN): 2
# Accuracy: 0.6630952380952381
# Precision: 0.015706806282722512
# Recall: 0.8181818181818182
# F1-score: 0.03082191780821918
# #################################################
# File: A4Benchmark-TS77.csv
# True Positives (TP): 13
# True Negatives (TN): 982
# False Positives (FP): 685
# False Negatives (FN): 0
# Accuracy: 0.5922619047619048
# Precision: 0.01862464183381089
# Recall: 1.0
# F1-score: 0.03656821378340366
# #################################################
# File: A4Benchmark-TS78.csv
# True Positives (TP): 13
# True Negatives (TN): 1187
# False Positives (FP): 480
# False Negatives (FN): 0
# Accuracy: 0.7142857142857143
# Precision: 0.02636916835699797
# Recall: 1.0
# F1-score: 0.05138339920948617
# #################################################
# File: A4Benchmark-TS79.csv
# True Positives (TP): 3
# True Negatives (TN): 1256
# False Positives (FP): 421
# False Negatives (FN): 0
# Accuracy: 0.7494047619047619
# Precision: 0.007075471698113208
# Recall: 1.0
# F1-score: 0.01405152224824356
# #################################################
# File: A4Benchmark-TS8.csv
# True Positives (TP): 11
# True Negatives (TN): 1125
# False Positives (FP): 542
# False Negatives (FN): 2
# Accuracy: 0.6761904761904762
# Precision: 0.019891500904159132
# Recall: 0.8461538461538461
# F1-score: 0.038869257950530034
# #################################################
# File: A4Benchmark-TS80.csv
# True Positives (TP): 9
# True Negatives (TN): 1066
# False Positives (FP): 602
# False Negatives (FN): 3
# Accuracy: 0.6398809523809523
# Precision: 0.014729950900163666
# Recall: 0.75
# F1-score: 0.028892455858747994
# #################################################
# File: A4Benchmark-TS81.csv
# True Positives (TP): 9
# True Negatives (TN): 997
# False Positives (FP): 674
# False Negatives (FN): 0
# Accuracy: 0.5988095238095238
# Precision: 0.013177159590043924
# Recall: 1.0
# F1-score: 0.026011560693641623
# #################################################
# File: A4Benchmark-TS82.csv
# True Positives (TP): 14
# True Negatives (TN): 919
# False Positives (FP): 747
# False Negatives (FN): 0
# Accuracy: 0.5553571428571429
# Precision: 0.018396846254927726
# Recall: 1.0
# F1-score: 0.03612903225806451
# #################################################
# File: A4Benchmark-TS83.csv
# True Positives (TP): 3
# True Negatives (TN): 1229
# False Positives (FP): 448
# False Negatives (FN): 0
# Accuracy: 0.7333333333333333
# Precision: 0.0066518847006651885
# Recall: 1.0
# F1-score: 0.013215859030837005
# #################################################
# File: A4Benchmark-TS84.csv
# True Positives (TP): 3
# True Negatives (TN): 1146
# False Positives (FP): 531
# False Negatives (FN): 0
# Accuracy: 0.6839285714285714
# Precision: 0.0056179775280898875
# Recall: 1.0
# F1-score: 0.0111731843575419
# #################################################
# File: A4Benchmark-TS85.csv
# True Positives (TP): 16
# True Negatives (TN): 991
# False Positives (FP): 673
# False Negatives (FN): 0
# Accuracy: 0.5994047619047619
# Precision: 0.023222060957910014
# Recall: 1.0
# F1-score: 0.04539007092198582
# #################################################
# File: A4Benchmark-TS86.csv
# True Positives (TP): 15
# True Negatives (TN): 981
# False Positives (FP): 684
# False Negatives (FN): 0
# Accuracy: 0.5928571428571429
# Precision: 0.02145922746781116
# Recall: 1.0
# F1-score: 0.04201680672268908
# #################################################
# File: A4Benchmark-TS87.csv
# True Positives (TP): 1
# True Negatives (TN): 935
# False Positives (FP): 744
# False Negatives (FN): 0
# Accuracy: 0.5571428571428572
# Precision: 0.0013422818791946308
# Recall: 1.0
# F1-score: 0.002680965147453083
# #################################################
# File: A4Benchmark-TS88.csv
# True Positives (TP): 12
# True Negatives (TN): 1019
# False Positives (FP): 648
# False Negatives (FN): 1
# Accuracy: 0.6136904761904762
# Precision: 0.01818181818181818
# Recall: 0.9230769230769231
# F1-score: 0.03566121842496285
# #################################################
# File: A4Benchmark-TS89.csv
# True Positives (TP): 9
# True Negatives (TN): 966
# False Positives (FP): 705
# False Negatives (FN): 0
# Accuracy: 0.5803571428571429
# Precision: 0.012605042016806723
# Recall: 1.0
# F1-score: 0.024896265560165977
# #################################################
# File: A4Benchmark-TS9.csv
# True Positives (TP): 1
# True Negatives (TN): 1039
# False Positives (FP): 640
# False Negatives (FN): 0
# Accuracy: 0.6190476190476191
# Precision: 0.0015600624024961
# Recall: 1.0
# F1-score: 0.0031152647975077885
# #################################################
# File: A4Benchmark-TS90.csv
# True Positives (TP): 12
# True Negatives (TN): 1009
# False Positives (FP): 659
# False Negatives (FN): 0
# Accuracy: 0.6077380952380952
# Precision: 0.01788375558867362
# Recall: 1.0
# F1-score: 0.035139092240117124
# #################################################
# File: A4Benchmark-TS91.csv
# True Positives (TP): 8
# True Negatives (TN): 1335
# False Positives (FP): 333
# False Negatives (FN): 4
# Accuracy: 0.799404761904762
# Precision: 0.02346041055718475
# Recall: 0.6666666666666666
# F1-score: 0.0453257790368272
# #################################################
# File: A4Benchmark-TS92.csv
# True Positives (TP): 15
# True Negatives (TN): 1172
# False Positives (FP): 493
# False Negatives (FN): 0
# Accuracy: 0.7065476190476191
# Precision: 0.02952755905511811
# Recall: 1.0
# F1-score: 0.05736137667304016
# #################################################
# File: A4Benchmark-TS93.csv
# True Positives (TP): 6
# True Negatives (TN): 954
# False Positives (FP): 720
# False Negatives (FN): 0
# Accuracy: 0.5714285714285714
# Precision: 0.008264462809917356
# Recall: 1.0
# F1-score: 0.01639344262295082
# #################################################
# File: A4Benchmark-TS94.csv
# True Positives (TP): 12
# True Negatives (TN): 1121
# False Positives (FP): 546
# False Negatives (FN): 1
# Accuracy: 0.674404761904762
# Precision: 0.021505376344086023
# Recall: 0.9230769230769231
# F1-score: 0.042031523642732056
# #################################################
# File: A4Benchmark-TS95.csv
# True Positives (TP): 5
# True Negatives (TN): 952
# False Positives (FP): 723
# False Negatives (FN): 0
# Accuracy: 0.5696428571428571
# Precision: 0.006868131868131868
# Recall: 1.0
# F1-score: 0.013642564802182811
# #################################################
# File: A4Benchmark-TS96.csv
# True Positives (TP): 1
# True Negatives (TN): 951
# False Positives (FP): 727
# False Negatives (FN): 1
# Accuracy: 0.5666666666666667
# Precision: 0.0013736263736263737
# Recall: 0.5
# F1-score: 0.0027397260273972607
# #################################################
# File: A4Benchmark-TS97.csv
# True Positives (TP): 15
# True Negatives (TN): 1077
# False Positives (FP): 587
# False Negatives (FN): 1
# Accuracy: 0.65
# Precision: 0.024916943521594685
# Recall: 0.9375
# F1-score: 0.04854368932038835
# #################################################
# File: A4Benchmark-TS98.csv
# True Positives (TP): 12
# True Negatives (TN): 1058
# False Positives (FP): 607
# False Negatives (FN): 3
# Accuracy: 0.6369047619047619
# Precision: 0.01938610662358643
# Recall: 0.8
# F1-score: 0.03785488958990536
# #################################################
# File: A4Benchmark-TS99.csv
# True Positives (TP): 9
# True Negatives (TN): 1192
# False Positives (FP): 472
# False Negatives (FN): 7
# Accuracy: 0.7148809523809524
# Precision: 0.018711018711018712
# Recall: 0.5625
# F1-score: 0.036217303822937634
# #################################################

# %% [markdown]
# # Another test with some modifications

# %%
# Path to your dataset folder
dataset_folder = "./A4Benchmark"

# Functions for anomaly detection and evaluation
def sliding_window_std(df, column_name, window_size, threshold):
    results = []
    problem_vals = []  # List to store values that exceed the threshold

    for i in range(len(df)):
        # Calculate the window boundaries
        start_index = max(0, i - window_size // 2)
        end_index = min(len(df), i + window_size // 2 + 1)
        
        # Get the numbers within the window
        window = df[column_name].iloc[start_index:end_index]
        
        # Calculate the standard deviation of the window
        std_dev = window.std()
        
        # Append the result to the results list
        # result list conations 3 things (number, window,std of the window)
        results.append((i, df.iloc[i][column_name], window.tolist(), std_dev))
        # print(results[i],'\n')

        if len(results) <= 2:
            # print("Skipping iteration#", i)
            # print("##################################################")
            continue
            
        if len(results) >= 3:
            # print("val1:",results[-3][3])
            # print("val2:",results[-2][3])
            # print("current std:",std_dev)
            # print("current iteration:", i)
            # print("##################################################")

            avg_prev_results = (results[-2][3] + results[-3][3]) / 2
            threshold_value = avg_prev_results + threshold

            if std_dev > threshold_value:
                problem_vals.append((i - window_size // 2, window.iloc[-1]))

            # print('Problem list:', problem_vals)
    return results, problem_vals

def actual_anomaly(df):
    anomaly_rows = []

    # Iterate over each row in the DataFrame
    for i, row in df.iterrows():
        if row['anomaly'] == 1:
            # Append a tuple containing the row number and the value from the 'anomaly' column to the result list
            anomaly_rows.append((i, row['value']))
    # print(anomaly_rows)
    return anomaly_rows

def find_normal_values(original_lst, anomaly_lst):
    normal_values = []
    for num in original_lst:
        is_anomaly = False
        for win_num, value in anomaly_lst:
            if num == value:
                is_anomaly = True
                break
        if not is_anomaly:
            normal_values.append(num)
    return normal_values

def finding_row_number(original_lst, anomaly_lst):
    rows = []
    i = 1
    for num in original_lst:
        i +=1
        for win_num, value in anomaly_lst:
            if num == value:
                rows.append((i,num))
    return rows

def categorize_points(original_lst, anomaly_lst):
    normal = []
    seasonal = []
    anomalies = []

    for i, num in enumerate(original_lst):
        if num not in (value for _, value in anomaly_lst):
            normal.append((i, num))
        elif i % 12 == 0 or i % 168 ==0:
            seasonal.append((i, num))
        else:
            anomalies.append((i, num))

    return normal, seasonal, anomalies

def evaluate_anomaly_detection(true_labels, predicted_labels):
    # Generate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)

    # Extract true positives (TP) and true negatives (TN)
    TP = cm[1, 1]  # Actual positive (1) and predicted positive (1)
    TN = cm[0, 0]  # Actual negative (0) and predicted negative (0)
    FP = cm[0, 1]  # Actual negative (0) but predicted positive (1)
    FN = cm[1, 0]  # Actual positive (1) but predicted negative (0)

    # # Output true positives (TP), true negatives (TN), false positives (FP), and false negatives (FN)
    # print("True Positives (TP):", TP)
    # print("True Negatives (TN):", TN)
    # print("False Positives (FP):", FP)
    # print("False Negatives (FN):", FN)

    # # Generate classification report
    # report = classification_report(true_labels, predicted_labels)
    # print("\nClassification Report:\n", report)

    # Calculate Accuracy
    accuracy = (TP + TN) / (TP + TN + FP + FN)

    # Calculate Precision
    precision = TP / (TP + FP)

    # Calculate Recall
    recall = TP / (TP + FN)

    # Calculate F1-score
    f1_score = 2 * (precision * recall) / (precision + recall)

    # print("Accuracy:", accuracy)
    # print("Precision:", precision)
    # print("Recall:", recall)
    # print("F1-score:", f1_score)

    return precision

# Function to apply your model and calculate accuracy
def apply_model_and_calculate_accuracy(df, column_name, window_size, threshold):
    std_devs, anomalies = sliding_window_std(df, column_name, window_size, threshold)
    actual = actual_anomaly(df)
    normal_values = find_normal_values(df[column_name], anomalies)
    
    anomaly_row_list = finding_row_number(df[column_name], anomalies)
    normal_list, seasonal_anomalies, other_anomalies = categorize_points(df['value'], anomaly_row_list)
    
    # Initialize and mark predicted anomalies
    df['predicted_anomalies'] = 0
    for anomaly_index, _ in other_anomalies:
        df.at[anomaly_index, 'predicted_anomalies'] = 1
    
    # Evaluate anomaly detection and return accuracy
    precision = evaluate_anomaly_detection(df['anomaly'], df['predicted_anomalies'])
    return precision

# Dictionary to store accuracy results
accuracy_results = {}

# Specify the column name containing the data
column_name = 'value'

def grid_search(df, column_name):
    best_precision = 0
    best_window_size = 0
    best_threshold = 0
    
    # Define the range of values to search over
    window_sizes = range(3, 21)  # Adjust range as needed
    thresholds = range(5, 21)  # Adjust range as needed
    
    # Iterate over all combinations of window sizes and thresholds
    for window_size in window_sizes:
        for threshold in thresholds:
            # Apply your model and calculate accuracy
            precision = apply_model_and_calculate_accuracy(df, column_name, window_size, threshold)
            
            # Update best parameters if accuracy is improved
            if precision > best_precision:
                best_precision = precision
                best_window_size = window_size
                best_threshold = threshold
    
    return best_window_size, best_threshold, best_precision

# Iterate through each file in the directory
for filename in sorted(os.listdir(dataset_folder)):
    if filename.endswith(".csv"):
        file_path = os.path.join(dataset_folder, filename)
        # Load CSV file
        df = pd.read_csv(file_path)
        
        # Perform grid search to find the best window size and threshold
        best_window_size, best_threshold, best_precision = grid_search(df, column_name)
        
        # Print the best parameters and accuracy
        print(f"File: {filename}, Best Window Size: {best_window_size}, Best Threshold: {best_threshold}, Precision: {best_precision}")

# Print accuracy results
for filename, accuracy in accuracy_results.items():
    print(f"File: {filename}, Precision: {precision}")
# Out:
# File: A4Benchmark-TS1.csv, Best Window Size: 16, Best Threshold: 19, Precision: 0.8
# File: A4Benchmark-TS10.csv, Best Window Size: 20, Best Threshold: 20, Precision: 0.017857142857142856
# File: A4Benchmark-TS2.csv, Best Window Size: 12, Best Threshold: 17, Precision: 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 188
#     185 df = pd.read_csv(file_path)
#     187 # Perform grid search to find the best window size and threshold
# --> 188 best_window_size, best_threshold, best_precision = grid_search(df, column_name)
#     190 # Print the best parameters and accuracy
#     191 print(f"File: {filename}, Best Window Size: {best_window_size}, Best Threshold: {best_threshold}, Precision: {best_precision}")
#
# Cell In[9], line 170, in grid_search(df, column_name)
#     167 for window_size in window_sizes:
#     168     for threshold in thresholds:
#     169         # Apply your model and calculate accuracy
# --> 170         precision = apply_model_and_calculate_accuracy(df, column_name, window_size, threshold)
#     172         # Update best parameters if accuracy is improved
#     173         if precision > best_precision:
#
# Cell In[9], line 135, in apply_model_and_calculate_accuracy(df, column_name, window_size, threshold)
#     134 def apply_model_and_calculate_accuracy(df, column_name, window_size, threshold):
# --> 135     std_devs, anomalies = sliding_window_std(df, column_name, window_size, threshold)
#     136     actual = actual_anomaly(df)
#     137     normal_values = find_normal_values(df[column_name], anomalies)
#
# Cell In[9], line 22, in sliding_window_std(df, column_name, window_size, threshold)
#      18 std_dev = window.std()
#      20 # Append the result to the results list
#      21 # result list conations 3 things (number, window,std of the window)
# ---> 22 results.append((i, df.iloc[i][column_name], window.tolist(), std_dev))
#      23 # print(results[i],'\n')
#      25 if len(results) <= 2:
#      26     # print("Skipping iteration#", i)
#      27     # print("##################################################")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1716, in _iLocIndexer._getitem_axis(self, key, axis)
#    1713 # validate the location
#    1714 self._validate_integer(key, axis)
# -> 1716 return self.obj._ixs(key, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3789, in DataFrame._ixs(self, i, axis)
#    3787 # irow
#    3788 if axis == 0:
# -> 3789     new_mgr = self._mgr.fast_xs(i)
#    3791     # if we are a copy, mark as such
#    3792     copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:980, in BlockManager.fast_xs(self, loc)
#     975     result = ensure_wrapped_if_datetimelike(result)
#     977 for blk in self.blocks:
#     978     # Such assignment may incorrectly coerce NaT to None
#     979     # result[blk.mgr_locs] = blk._slice((slice(None), loc))
# --> 980     for i, rl in enumerate(blk.mgr_locs):
#     981         result[rl] = blk.iget((i, loc))
#     983 if isinstance(dtype, ExtensionDtype):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:239, in Block.mgr_locs(self)
#     236         value = self.fill_value
#     237     return value
# --> 239 @property
#     240 def mgr_locs(self) -> BlockPlacement:
#     241     return self._mgr_locs
#     243 @mgr_locs.setter
#     244 def mgr_locs(self, new_mgr_locs: BlockPlacement) -> None:
#
# KeyboardInterrupt:
